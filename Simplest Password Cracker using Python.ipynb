# %%
import random

# %%
chars =  "abcdefghijklmnopqrstuvwxyz1234567890"

# %%
char_list = list(chars)

# %%
password="s1"

# %%
guess=""

# %%
while(guess !=password):
  guess = random.choices(char_list, k=len(password))
  print(str(guess))
  if (guess==list(password)):
    print("your password"+"".join(guess))
    input()
    break
# Out:
# ['p', '3']
# ['g', 'u']
# ['v', 'v']
# ['7', '1']
# ['4', 'o']
# ['f', 'u']
# ['e', '0']
# ['h', 'b']
# ['5', 'g']
# ['p', 'm']
# ['n', '6']
# ['9', '5']
# ['w', '7']
# ['o', 'n']
# ['o', 'e']
# ['i', '6']
# ['e', 'f']
# ['7', 'z']
# ['f', 'g']
# ['t', '5']
# ['v', 'b']
# ['0', '2']
# ['e', 'h']
# ['6', '5']
# ['8', 'w']
# ['o', 'w']
# ['y', 'i']
# ['p', 'u']
# ['f', 'y']
# ['a', '7']
# ['o', 't']
# ['e', '0']
# ['o', 's']
# ['5', 'd']
# ['5', '1']
# ['1', '1']
# ['2', '9']
# ['1', 'm']
# ['e', 'm']
# ['7', '2']
# ['f', 'g']
# ['a', 'o']
# ['3', 'm']
# ['k', '5']
# ['9', 'u']
# ['x', 'z']
# ['4', '3']
# ['5', 'c']
# ['8', '1']
# ['3', 'j']
# ['c', '1']
# ['1', '3']
# ['w', 'd']
# ['p', 'g']
# ['j', 's']
# ['y', '3']
# ['b', 'b']
# ['q', 'a']
# ['l', 'z']
# ['v', 'i']
# ['a', 'v']
# ['v', 'g']
# ['l', 'x']
# ['z', '0']
# ['c', '1']
# ['t', 'c']
# ['x', 'n']
# ['r', '5']
# ['p', 'l']
# ['t', '5']
# ['a', '8']
# ['w', 'v']
# ['l', 'w']
# ['d', 'r']
# ['n', 'x']
# ['i', 'v']
# ['a', 'z']
# ['4', 'x']
# ['p', 'n']
# ['g', 'w']
# ['4', 'n']
# ['l', 'y']
# ['h', 'k']
# ['4', 'r']
# ['m', 'v']
# ['7', 'u']
# ['l', 'g']
# ['r', 'x']
# ['h', 'k']
# ['0', '7']
# ['o', 'u']
# ['b', 'h']
# ['8', 'd']
# ['f', 'e']
# ['f', 'h']
# ['n', 'r']
# ['2', 'g']
# ['5', 'd']
# ['5', '8']
# ['o', '9']
# ['0', '2']
# ['1', '4']
# ['m', '7']
# ['v', '4']
# ['2', 'r']
# ['a', '2']
# ['c', 'y']
# ['7', 'o']
# ['4', 'n']
# ['e', '8']
# ['f', 'u']
# ['a', 'o']
# ['y', 's']
# ['h', 'z']
# ['g', '4']
# ['l', '5']
# ['h', 'u']
# ['f', 'g']
# ['s', 'n']
# ['w', '6']
# ['v', 'r']
# ['3', 'm']
# ['g', '8']
# ['m', 'b']
# ['k', 'j']
# ['r', '6']
# ['6', 'u']
# ['d', '4']
# ['q', 'm']
# ['8', 't']
# ['x', 'b']
# ['x', 'x']
# ['7', 'a']
# ['r', '7']
# ['d', '5']
# ['z', 'j']
# ['q', '5']
# ['w', 't']
# ['a', 'k']
# ['b', '6']
# ['2', 'm']
# ['q', '8']
# ['5', 'w']
# ['s', 'h']
# ['6', 't']
# ['o', '7']
# ['6', 'a']
# ['1', '3']
# ['b', 'e']
# ['0', 's']
# ['2', 'o']
# ['v', 'x']
# ['7', 'z']
# ['a', 'h']
# ['2', 'n']
# ['t', '4']
# ['a', '1']
# ['k', '3']
# ['j', 'l']
# ['z', 'z']
# ['y', 'g']
# ['o', 'n']
# ['p', '2']
# ['0', 's']
# ['l', '3']
# ['5', 'e']
# ['6', 'k']
# ['u', 'n']
# ['l', 'k']
# ['i', 'q']
# ['a', '3']
# ['w', 'u']
# ['d', 't']
# ['4', 'e']
# ['a', '2']
# ['j', 'm']
# ['i', 'h']
# ['1', '2']
# ['f', 'n']
# ['y', 'm']
# ['2', '1']
# ['z', 'p']
# ['o', '6']
# ['0', '6']
# ['i', '0']
# ['j', 'd']
# ['c', 'y']
# ['b', 't']
# ['c', '0']
# ['5', 'h']
# ['7', 'q']
# ['q', 'q']
# ['h', 'b']
# ['i', 'l']
# ['t', '0']
# ['5', 'o']
# ['u', '2']
# ['c', '0']
# ['0', 'k']
# ['0', '7']
# ['2', '4']
# ['s', 'x']
# ['l', 'l']
# ['l', '2']
# ['d', 'x']
# ['q', '4']
# ['x', 'b']
# ['l', 'm']
# ['x', '0']
# ['v', 'b']
# ['g', 'c']
# ['i', 'q']
# ['l', '5']
# ['t', 'x']
# ['q', 'c']
# ['e', 'j']
# ['j', 'r']
# ['p', 'k']
# ['0', 'p']
# ['i', '4']
# ['v', 'c']
# ['m', '9']
# ['p', '3']
# ['5', 'z']
# ['0', 'b']
# ['z', 'j']
# ['i', '8']
# ['2', 'h']
# ['p', 'r']
# ['h', '7']
# ['1', 'q']
# ['8', '0']
# ['p', 'n']
# ['m', '8']
# ['i', 'b']
# ['3', 'n']
# ['z', 'r']
# ['o', 'q']
# ['j', 't']
# ['e', '1']
# ['i', '7']
# ['6', 'l']
# ['i', 'e']
# ['5', 'n']
# ['i', 'b']
# ['i', 's']
# ['e', 'l']
# ['o', 'd']
# ['z', 'h']
# ['g', '7']
# ['x', 'f']
# ['k', 'h']
# ['s', 'f']
# ['q', '0']
# ['b', 'z']
# ['9', '6']
# ['q', 'o']
# ['a', 'q']
# ['p', 'w']
# ['u', 'k']
# ['x', 'z']
# ['m', 'a']
# ['t', 'j']
# ['e', 'i']
# ['f', 'l']
# ['b', 'i']
# ['y', '5']
# ['o', '7']
# ['7', '8']
# ['z', 'k']
# ['u', 'e']
# ['j', 'f']
# ['p', 'p']
# ['u', '0']
# ['r', 's']
# ['p', 'x']
# ['z', 'i']
# ['g', 'b']
# ['y', '9']
# ['v', 'u']
# ['j', 'f']
# ['q', 'a']
# ['8', '4']
# ['6', '5']
# ['1', 'q']
# ['z', '8']
# ['f', 'c']
# ['c', 'u']
# ['z', 'x']
# ['x', '4']
# ['b', 'g']
# ['s', '5']
# ['d', 'h']
# ['3', 'h']
# ['b', 'q']
# ['g', '3']
# ['8', 'x']
# ['t', 'l']
# ['z', '7']
# ['n', 'u']
# ['x', '0']
# ['v', 'c']
# ['b', '9']
# ['l', 'w']
# ['4', 'v']
# ['u', 'd']
# ['a', '8']
# ['l', 's']
# ['n', 'x']
# ['u', 'p']
# ['v', 'a']
# ['1', 'c']
# ['x', 'j']
# ['a', 'o']
# ['u', '4']
# ['x', '9']
# ['q', '1']
# ['g', '2']
# ['c', 'a']
# ['4', '0']
# ['r', 'k']
# ['7', 'w']
# ['b', 'e']
# ['e', '2']
# ['l', '2']
# ['z', 'b']
# ['2', 'x']
# ['0', 'f']
# ['x', 'x']
# ['m', 'c']
# ['1', 'f']
# ['g', '9']
# ['a', 'j']
# ['2', 'x']
# ['q', '6']
# ['b', '7']
# ['2', 'z']
# ['r', '4']
# ['5', '2']
# ['v', 'k']
# ['j', 'v']
# ['9', 'r']
# ['v', 'l']
# ['5', 'c']
# ['s', '7']
# ['c', 't']
# ['q', 'i']
# ['8', '3']
# ['f', 'w']
# ['w', '1']
# ['i', 'd']
# ['b', '3']
# ['1', 'j']
# ['b', 'b']
# ['g', 'a']
# ['i', 'a']
# ['1', 'k']
# ['8', 'y']
# ['p', 'j']
# ['8', 'm']
# ['5', 'p']
# ['9', '6']
# ['v', 'g']
# ['g', 'w']
# ['r', 'y']
# ['r', 'n']
# ['h', '3']
# ['f', 'r']
# ['4', 'g']
# ['x', 'q']
# ['f', 'i']
# ['w', 'o']
# ['s', 's']
# ['y', 'g']
# ['4', 'n']
# ['t', 'k']
# ['v', 'd']
# ['9', 'm']
# ['m', '7']
# ['j', '9']
# ['l', 'y']
# ['k', 'a']
# ['h', 'w']
# ['a', '7']
# ['w', 'q']
# ['9', 'c']
# ['w', 'd']
# ['k', '1']
# ['j', 'l']
# ['n', 'x']
# ['1', 'g']
# ['t', 'f']
# ['q', 'u']
# ['w', 'l']
# ['p', 'g']
# ['5', '8']
# ['9', 'o']
# ['t', 'q']
# ['7', '1']
# ['4', '7']
# ['a', 'r']
# ['n', 'h']
# ['g', 'a']
# ['y', 'u']
# ['4', '7']
# ['k', 'd']
# ['q', 'g']
# ['t', 'k']
# ['4', 'r']
# ['m', 'x']
# ['t', 'y']
# ['u', 'i']
# ['a', 'p']
# ['h', 'k']
# ['8', 'n']
# ['8', '1']
# ['h', 'i']
# ['l', 's']
# ['4', '0']
# ['m', '4']
# ['8', '2']
# ['v', '6']
# ['t', 'f']
# ['b', 't']
# ['q', 'z']
# ['m', 'h']
# ['g', '4']
# ['x', 'y']
# ['u', '2']
# ['7', '7']
# ['g', '3']
# ['2', 'x']
# ['n', 'l']
# ['q', '2']
# ['q', 'j']
# ['5', 'n']
# ['i', '0']
# ['o', '7']
# ['4', 'z']
# ['n', '0']
# ['m', '1']
# ['t', 'a']
# ['7', 'e']
# ['6', 'q']
# ['2', '6']
# ['1', 'a']
# ['3', 'k']
# ['t', 't']
# ['a', '1']
# ['y', '7']
# ['6', 'b']
# ['2', 'e']
# ['5', 'v']
# ['g', '9']
# ['9', 'z']
# ['b', 'z']
# ['x', 's']
# ['b', '4']
# ['8', 'b']
# ['l', '6']
# ['o', 'i']
# ['y', 'u']
# ['v', '8']
# ['k', 'c']
# ['w', 'h']
# ['a', 'r']
# ['m', 'y']
# ['d', 'j']
# ['u', 'i']
# ['j', 'l']
# ['z', 'g']
# ['u', '5']
# ['i', 'r']
# ['j', 'h']
# ['i', 'b']
# ['4', 'i']
# ['j', 'g']
# ['2', '6']
# ['5', 'm']
# ['9', '1']
# ['j', 'r']
# ['q', '0']
# ['3', 'i']
# ['6', 'e']
# ['2', 'd']
# ['c', 'o']
# ['u', 'q']
# ['n', 'n']
# ['3', '2']
# ['a', 'w']
# ['e', 'r']
# ['t', 'y']
# ['m', 'q']
# ['h', 's']
# ['n', '4']
# ['k', 'd']
# ['e', 'd']
# ['e', 'o']
# ['9', '4']
# ['k', 'r']
# ['h', 'l']
# ['w', 'd']
# ['o', 'r']
# ['7', 'm']
# ['2', 'v']
# ['n', 'k']
# ['5', 'g']
# ['5', 'q']
# ['v', 'w']
# ['w', '0']
# ['c', 'w']
# ['b', '8']
# ['i', 'n']
# ['0', 'k']
# ['z', 'z']
# ['1', 'm']
# ['2', '5']
# ['z', '1']
# ['k', 'o']
# ['9', 'g']
# ['d', 'i']
# ['9', 'd']
# ['v', 'u']
# ['9', 'v']
# ['e', '9']
# ['6', 'z']
# ['e', 'j']
# ['h', '2']
# ['r', '8']
# ['a', 'h']
# ['8', '6']
# ['o', 'm']
# ['l', 't']
# ['3', '0']
# ['8', 'm']
# ['r', 'v']
# ['2', 'k']
# ['e', 'a']
# ['2', 'u']
# ['8', 'h']
# ['l', '6']
# ['h', '5']
# ['9', 'd']
# ['d', '0']
# ['v', '7']
# ['w', 'c']
# ['5', 'g']
# ['x', 'j']
# ['4', 'm']
# ['q', '8']
# ['j', 'o']
# ['q', 'a']
# ['k', '9']
# ['y', '5']
# ['7', 'j']
# ['s', 'a']
# ['i', 's']
# ['u', '2']
# ['5', 'o']
# ['3', 'a']
# ['5', '0']
# ['n', 'p']
# ['e', 'u']
# ['0', '6']
# ['0', 'o']
# ['1', '4']
# ['z', 'v']
# ['4', 'v']
# ['7', 's']
# ['c', '5']
# ['3', '9']
# ['w', 'x']
# ['f', 'u']
# ['i', 'r']
# ['c', 'i']
# ['u', 'k']
# ['y', 't']
# ['m', 'c']
# ['4', 'b']
# ['b', 'b']
# ['6', 'j']
# ['9', 'l']
# ['v', 't']
# ['3', 'd']
# ['w', 'w']
# ['d', 'y']
# ['q', 's']
# ['h', 'l']
# ['h', 'r']
# ['n', 'f']
# ['l', 'm']
# ['c', '7']
# ['6', '1']
# ['m', 's']
# ['q', 'x']
# ['k', '9']
# ['u', 'f']
# ['h', 'v']
# ['k', 't']
# ['5', 'f']
# ['d', 'z']
# ['a', '7']
# ['h', 'o']
# ['b', 'a']
# ['p', 'j']
# ['i', 'g']
# ['v', 'q']
# ['m', 'c']
# ['x', 'k']
# ['4', '0']
# ['j', 'f']
# ['x', '9']
# ['u', 'w']
# ['m', 'i']
# ['d', 'a']
# ['f', 'p']
# ['o', 's']
# ['d', '3']
# ['a', '9']
# ['4', 'd']
# ['a', '3']
# ['y', 'x']
# ['l', 'c']
# ['l', 'o']
# ['9', 'e']
# ['g', 'p']
# ['c', '2']
# ['g', 'f']
# ['j', 'p']
# ['8', 'x']
# ['r', 'h']
# ['a', '9']
# ['3', 'u']
# ['2', 'z']
# ['3', '9']
# ['b', 'j']
# ['o', 'h']
# ['5', 'e']
# ['x', '9']
# ['q', 'e']
# ['1', 's']
# ['v', 's']
# ['k', '4']
# ['j', '5']
# ['j', 'k']
# ['4', '3']
# ['a', 'l']
# ['o', '5']
# ['w', '9']
# ['p', 'f']
# ['d', 'y']
# ['p', 'g']
# ['9', 'h']
# ['b', 'f']
# ['z', '6']
# ['9', 'm']
# ['b', '9']
# ['6', '7']
# ['1', 's']
# ['s', 'f']
# ['p', 'i']
# ['r', 'k']
# ['z', '5']
# ['a', '5']
# ['6', 'n']
# ['l', 'u']
# ['t', '7']
# ['t', 'u']
# ['h', 'i']
# ['h', '0']
# ['p', 'z']
# ['r', 'v']
# ['m', '0']
# ['v', '1']
# ['4', 'e']
# ['d', 'z']
# ['r', '3']
# ['9', 'k']
# ['2', '3']
# ['v', 'r']
# ['n', 'i']
# ['m', 'j']
# ['z', 'v']
# ['x', 'c']
# ['b', '8']
# ['i', 'z']
# ['4', 'n']
# ['j', 'z']
# ['y', 'l']
# ['9', 'c']
# ['q', 'a']
# ['m', '1']
# ['g', 'd']
# ['n', 'y']
# ['c', '7']
# ['x', 'm']
# ['q', 'v']
# ['t', 'y']
# ['k', '2']
# ['s', 'x']
# ['6', 'f']
# ['r', '5']
# ['m', '5']
# ['c', 'r']
# ['0', 'g']
# ['r', 'j']
# ['h', 'j']
# ['u', 'p']
# ['o', 'e']
# ['k', '5']
# ['m', 'o']
# ['p', '7']
# ['9', 'n']
# ['e', '5']
# ['b', 'n']
# ['v', 'd']
# ['0', '2']
# ['e', '5']
# ['0', 'v']
# ['i', 'j']
# ['c', 'b']
# ['7', 'g']
# ['5', 'l']
# ['n', 'z']
# ['i', '8']
# ['d', 'k']
# ['o', 'h']
# ['o', 'i']
# ['z', '5']
# ['h', 'h']
# ['k', 'b']
# ['g', 'l']
# ['q', 'm']
# ['4', '2']
# ['7', '7']
# ['4', 'a']
# ['c', '5']
# ['g', 'z']
# ['p', '0']
# ['e', 's']
# ['5', '7']
# ['n', 'l']
# ['7', 'q']
# ['b', '8']
# ['r', '5']
# ['m', 'l']
# ['f', 'f']
# ['4', '6']
# ['e', 'o']
# ['o', 'b']
# ['j', '4']
# ['6', 'y']
# ['0', 'z']
# ['i', 's']
# ['q', 'q']
# ['h', 'r']
# ['b', 'k']
# ['c', '2']
# ['v', 'b']
# ['v', 'm']
# ['o', 'j']
# ['w', '3']
# ['f', 'v']
# ['q', 'l']
# ['x', 'd']
# ['k', 'v']
# ['h', 'u']
# ['l', '0']
# ['x', 'v']
# ['n', '9']
# ['5', 'w']
# ['z', 'h']
# ['2', 'j']
# ['a', 'a']
# ['a', '0']
# ['j', '5']
# ['7', '7']
# ['8', 'a']
# ['4', '1']
# ['r', 'k']
# ['y', 'j']
# ['h', 'g']
# ['8', 'f']
# ['i', '0']
# ['y', '5']
# ['f', 't']
# ['v', 'z']
# ['4', '8']
# ['j', '1']
# ['y', 'i']
# ['r', 'f']
# ['8', 's']
# ['8', 'g']
# ['8', 'c']
# ['h', 'l']
# ['f', 'q']
# ['f', 'w']
# ['2', 'y']
# ['x', 'l']
# ['0', 'u']
# ['p', '1']
# ['w', 'p']
# ['s', 't']
# ['o', 'k']
# ['i', 'k']
# ['1', '3']
# ['t', 'v']
# ['p', '4']
# ['d', 'g']
# ['p', 'o']
# ['o', 's']
# ['5', '6']
# ['z', 'a']
# ['x', '9']
# ['0', 'u']
# ['a', 'n']
# ['q', 'i']
# ['p', 'c']
# ['k', 'z']
# ['j', '4']
# ['6', 's']
# ['d', '5']
# ['4', 'q']
# ['d', '2']
# ['i', '6']
# ['0', '5']
# ['3', 'a']
# ['3', 'l']
# ['9', 'z']
# ['9', 'a']
# ['b', '8']
# ['5', 'f']
# ['3', 't']
# ['o', 'z']
# ['d', 'z']
# ['x', '6']
# ['d', 'f']
# ['a', 'w']
# ['x', 'u']
# ['r', '2']
# ['y', '7']
# ['p', 'p']
# ['r', '1']
# ['m', 'h']
# ['1', 'w']
# ['u', 'r']
# ['6', 'c']
# ['o', '8']
# ['y', 'o']
# ['8', 'h']
# ['x', 'v']
# ['p', '4']
# ['r', 'm']
# ['t', 'x']
# ['0', 'e']
# ['s', 'x']
# ['6', 'e']
# ['c', '4']
# ['g', 'm']
# ['c', 'r']
# ['s', 'l']
# ['9', '9']
# ['0', 'z']
# ['5', 'b']
# ['r', 'l']
# ['k', 'x']
# ['c', '7']
# ['8', 'o']
# ['3', '1']
# ['t', 'c']
# ['h', '2']
# ['x', 'h']
# ['l', 'a']
# ['4', '7']
# ['f', 'i']
# ['h', '3']
# ['h', 'y']
# ['t', 'l']
# ['4', 'x']
# ['g', '4']
# ['2', '8']
# ['v', 'w']
# ['6', 'c']
# ['t', 'r']
# ['d', 'x']
# ['z', 'k']
# ['v', '4']
# ['2', 'l']
# ['7', 'o']
# ['q', 'd']
# ['k', 'm']
# ['i', 'o']
# ['h', 'e']
# ['q', 'j']
# ['q', 'p']
# ['k', 'y']
# ['7', 'h']
# ['s', '2']
# ['y', 'f']
# ['x', 'j']
# ['y', 'g']
# ['u', '1']
# ['5', '7']
# ['c', 'q']
# ['i', '1']
# ['i', '4']
# ['x', '5']
# ['3', 'a']
# ['m', 'k']
# ['r', 'h']
# ['0', 'e']
# ['1', 'u']
# ['0', 'd']
# ['u', 'y']
# ['q', 'u']
# ['n', 'm']
# ['5', 'j']
# ['b', 'a']
# ['4', '5']
# ['x', '4']
# ['k', 'j']
# ['4', '9']
# ['1', 's']
# ['n', 'x']
# ['2', '5']
# ['a', 'w']
# ['6', 'a']
# ['6', '8']
# ['i', 'k']
# ['c', 't']
# ['k', 'e']
# ['k', 'j']
# ['d', '3']
# ['3', 'a']
# ['j', 'f']
# ['f', 'k']
# ['q', 'r']
# ['m', 's']
# ['w', 'b']
# ['y', 'd']
# ['c', '2']
# ['2', 'o']
# ['z', 't']
# ['6', '9']
# ['t', 's']
# ['o', '3']
# ['x', 'a']
# ['i', 's']
# ['6', 'u']
# ['l', 'x']
# ['g', '2']
# ['c', 'k']
# ['y', 'i']
# ['m', '5']
# ['v', 'j']
# ['1', 'v']
# ['v', 'k']
# ['j', '3']
# ['k', 'a']
# ['v', '5']
# ['r', '8']
# ['0', 'z']
# ['j', 'a']
# ['x', 'v']
# ['s', 'l']
# ['a', '0']
# ['o', 'w']
# ['0', 'm']
# ['8', 'f']
# ['a', 'w']
# ['j', 'f']
# ['1', 'u']
# ['s', 'd']
# ['d', '1']
# ['d', 'k']
# ['z', 'c']
# ['1', 'g']
# ['e', 'g']
# ['l', 'g']
# ['w', 'b']
# ['7', '2']
# ['z', 'w']
# ['n', 'k']
# ['l', 'u']
# ['k', 's']
# ['f', 'l']
# ['w', '5']
# ['z', 'z']
# ['v', 'e']
# ['m', 'v']
# ['j', '8']
# ['w', 'e']
# ['7', 'j']
# ['y', '5']
# ['2', '7']
# ['p', 'i']
# ['l', 'z']
# ['n', 'n']
# ['6', 'a']
# ['r', 'p']
# ['u', 'k']
# ['g', 'n']
# ['5', '7']
# ['j', 'u']
# ['7', 'h']
# ['1', 'c']
# ['6', '8']
# ['0', 'r']
# ['o', 'p']
# ['l', 'q']
# ['l', 'x']
# ['m', 'x']
# ['h', '8']
# ['l', 's']
# ['n', '4']
# ['b', 't']
# ['4', 'n']
# ['7', '5']
# ['8', 'l']
# ['4', 'g']
# ['1', '7']
# ['1', 'v']
# ['u', '6']
# ['8', 'o']
# ['t', 'i']
# ['b', 'y']
# ['g', 'b']
# ['d', 'i']
# ['f', 'u']
# ['0', 'u']
# ['d', '3']
# ['y', 'h']
# ['u', 'c']
# ['d', 'b']
# ['7', 'a']
# ['o', 'y']
# ['i', 'y']
# ['6', 'h']
# ['y', 't']
# ['7', 's']
# ['2', 'q']
# ['4', '5']
# ['c', '2']
# ['4', 'q']
# ['f', 'j']
# ['6', 'e']
# ['d', '0']
# ['8', 'y']
# ['6', '9']
# ['h', 'h']
# ['v', '2']
# ['9', '7']
# ['l', '9']
# ['0', '2']
# ['l', '6']
# ['2', 'p']
# ['p', 'b']
# ['y', '6']
# ['2', 'h']
# ['g', '9']
# ['9', 'y']
# ['y', 'c']
# ['l', 'i']
# ['c', 'i']
# ['8', 'm']
# ['o', 'p']
# ['n', '8']
# ['d', 'f']
# ['a', 'c']
# ['x', 't']
# ['k', '7']
# ['u', 'x']
# ['h', '1']
# ['q', 'n']
# ['z', 'o']
# ['c', 'x']
# ['g', 'w']
# ['l', '5']
# ['3', 'm']
# ['u', '8']
# ['z', '0']
# ['x', 'y']
# ['e', '4']
# ['6', '3']
# ['k', 'k']
# ['c', 'n']
# ['j', 'a']
# ['2', 'o']
# ['t', 'm']
# ['m', 'z']
# ['u', 'j']
# ['2', 'g']
# ['1', 's']
# ['6', '7']
# ['g', 'l']
# ['8', '9']
# ['z', 'e']
# ['4', 'i']
# ['m', 'h']
# ['j', 'n']
# ['2', 'p']
# ['j', '5']
# ['e', '4']
# ['b', 'h']
# ['p', 'z']
# ['s', 'q']
# ['6', '8']
# ['j', 'u']
# ['2', 't']
# ['0', '2']
# ['c', 'l']
# ['r', '3']
# ['r', '4']
# ['a', 'v']
# ['m', 'n']
# ['r', 'q']
# ['t', 's']
# ['p', 'r']
# ['c', '4']
# ['g', 'x']
# ['l', 't']
# ['3', 'a']
# ['e', 'z']
# ['g', '5']
# ['d', 'b']
# ['t', 'g']
# ['b', '3']
# ['p', 'n']
# ['d', 'b']
# ['j', '0']
# ['t', 't']
# ['o', 'z']
# ['o', '2']
# ['3', 'h']
# ['w', 'e']
# ['e', 'r']
# ['s', '0']
# ['g', '2']
# ['l', 'q']
# ['7', 'e']
# ['b', 'q']
# ['f', '1']
# ['7', 'c']
# ['m', '7']
# ['g', 'y']
# ['v', 'o']
# ['q', 'b']
# ['5', 'i']
# ['y', 'i']
# ['n', '7']
# ['k', 'k']
# ['1', '1']
# ['w', 'h']
# ['t', 'g']
# ['l', 'u']
# ['7', 'w']
# ['1', 'o']
# ['d', '5']
# ['1', 'j']
# ['7', '2']
# ['d', 'r']
# ['o', 'q']
# ['3', 'x']
# ['f', 'e']
# ['p', 'p']
# ['4', 'w']
# ['t', 'a']
# ['1', 'k']
# ['j', 'p']
# ['2', '0']
# ['k', '5']
# ['r', 'z']
# ['y', 'u']
# ['0', 'o']
# ['8', 'p']
# ['g', 'k']
# ['o', '5']
# ['l', 't']
# ['7', '3']
# ['4', '0']
# ['n', 'f']
# ['a', '0']
# ['d', 'o']
# ['y', 'b']
# ['u', 'z']
# ['p', 'p']
# ['p', '9']
# ['6', '3']
# ['r', 'e']
# ['c', 'e']
# ['r', 'f']
# ['z', 'b']
# ['s', 'j']
# ['6', '7']
# ['s', 'v']
# ['t', '4']
# ['h', '1']
# ['m', '7']
# ['j', 'm']
# ['3', 'y']
# ['t', '7']
# ['e', 'z']
# ['b', 'j']
# ['3', 'e']
# ['y', 's']
# ['o', 'm']
# ['5', 'c']
# ['a', 'w']
# ['j', 'l']
# ['h', 'h']
# ['p', '5']
# ['a', 'w']
# ['p', 's']
# ['i', '4']
# ['2', '6']
# ['f', 'j']
# ['k', 'e']
# ['e', '5']
# ['e', '9']
# ['c', 'w']
# ['0', 'm']
# ['a', 'y']
# ['v', 'b']
# ['r', '9']
# ['5', 'c']
# ['1', 'f']
# ['7', 'j']
# ['v', 'i']
# ['t', '4']
# ['u', 'k']
# ['7', 'g']
# ['1', 'x']
# ['9', '0']
# ['a', 'u']
# ['4', 'e']
# ['y', 'x']
# ['t', '2']
# ['0', 'j']
# ['q', '4']
# ['8', 'a']
# ['c', 'g']
# ['0', 'r']
# ['1', 'y']
# ['j', '9']
# ['t', 'f']
# ['r', 'c']
# ['r', 'n']
# ['u', 'd']
# ['c', 'j']
# ['9', 'm']
# ['i', 'j']
# ['n', 'd']
# ['w', 'a']
# ['2', 'q']
# ['q', 'v']
# ['h', 'j']
# ['m', '4']
# ['o', 'g']
# ['1', '1']
# ['z', 'r']
# ['b', '1']
# ['w', '8']
# ['f', 't']
# ['i', '3']
# ['6', 'o']
# ['3', 'a']
# ['a', 'b']
# ['4', 't']
# ['p', 'o']
# ['u', '9']
# ['k', '7']
# ['8', 'g']
# ['f', '4']
# ['8', 'j']
# ['4', 'p']
# ['p', '4']
# ['d', 'o']
# ['6', 'n']
# ['f', 'o']
# ['l', 'o']
# ['x', 'b']
# ['w', '6']
# ['i', '0']
# ['0', '1']
# ['1', '3']
# ['0', 'i']
# ['2', 'b']
# ['v', '3']
# ['4', '0']
# ['v', 'l']
# ['n', 'd']
# ['k', 'f']
# ['p', 's']
# ['v', 'v']
# ['u', 'u']
# ['4', '7']
# ['5', 's']
# ['8', 'i']
# ['5', 'l']
# ['y', '7']
# ['s', 'n']
# ['7', 'j']
# ['2', '8']
# ['l', 's']
# ['6', 'h']
# ['v', 't']
# ['g', '7']
# ['t', 'l']
# ['v', 's']
# ['d', '9']
# ['l', 'w']
# ['2', '9']
# ['4', 's']
# ['z', '0']
# ['n', 'v']
# ['u', 'f']
# ['v', 'c']
# ['y', '1']
# ['d', 'e']
# ['1', '5']
# ['f', '0']
# ['q', 'w']
# ['4', '0']
# ['p', 'y']
# ['r', 't']
# ['v', 'f']
# ['o', 'v']
# ['u', '3']
# ['6', '3']
# ['k', '6']
# ['6', 'v']
# ['8', '7']
# ['h', 'u']
# ['n', 'a']
# ['k', 'j']
# ['5', 'u']
# ['s', 'a']
# ['x', 'o']
# ['v', 'i']
# ['1', '7']
# ['l', 'h']
# ['h', 'z']
# ['w', '1']
# ['k', '2']
# ['p', 'b']
# ['o', '6']
# ['n', 'r']
# ['n', 'k']
# ['3', 'y']
# ['m', '2']
# ['k', 'm']
# ['1', '4']
# ['d', 'h']
# ['v', 't']
# ['7', 'i']
# ['d', 'g']
# ['w', 'o']
# ['b', '6']
# ['x', 'x']
# ['z', '2']
# ['9', 'd']
# ['k', 'b']
# ['l', 'x']
# ['x', 'z']
# ['d', 'z']
# ['y', '3']
# ['p', 'y']
# ['i', 'h']
# ['u', 'r']
# ['j', 'o']
# ['7', 'w']
# ['g', 'q']
# ['r', 'z']
# ['x', '8']
# ['3', 'm']
# ['o', 'm']
# ['p', '0']
# ['l', 'j']
# ['9', '3']
# ['7', 'z']
# ['b', '1']
# ['z', 'v']
# ['m', 'v']
# ['k', '8']
# ['3', 'g']
# ['x', 's']
# ['6', '7']
# ['p', 'c']
# ['8', 'b']
# ['l', '5']
# ['l', '2']
# ['8', 'j']
# ['p', 'm']
# ['e', 'g']
# ['e', '1']
# ['t', 't']
# ['u', 'k']
# ['0', 'n']
# ['a', 'k']
# ['z', 's']
# ['3', 'c']
# ['u', 'q']
# ['x', 'a']
# ['u', 'c']
# ['a', 'j']
# ['q', 's']
# ['0', 'y']
# ['2', 'w']
# ['6', '3']
# ['7', 'q']
# ['r', '0']
# ['y', 'x']
# ['2', 'g']
# ['d', 'l']
# ['p', 'k']
# ['q', '2']
# ['e', 'b']
# ['4', '3']
# ['h', 'c']
# ['u', 't']
# ['e', '7']
# ['r', 'v']
# ['f', 'k']
# ['6', '0']
# ['b', 'd']
# ['j', 'e']
# ['1', 'i']
# ['a', 'v']
# ['h', 'e']
# ['s', 'l']
# ['p', 'c']
# ['z', 'q']
# ['i', 'y']
# ['z', 'z']
# ['h', '2']
# ['e', 'k']
# ['3', '4']
# ['c', '2']
# ['4', 'c']
# ['q', 'z']
# ['7', 'q']
# ['5', 'm']
# ['d', 'a']
# ['g', 'y']
# ['q', 'e']
# ['k', 'v']
# ['r', '5']
# ['l', 'm']
# ['y', 'p']
# ['8', 'x']
# ['w', 'e']
# ['i', 'q']
# ['6', '9']
# ['b', '7']
# ['s', '2']
# ['h', 'f']
# ['s', 'z']
# ['8', 'q']
# ['6', 'a']
# ['2', 'l']
# ['b', '1']
# ['o', 'a']
# ['0', '9']
# ['n', 'g']
# ['s', 'r']
# ['k', 'o']
# ['h', 'r']
# ['b', 'l']
# ['c', 'l']
# ['r', 'b']
# ['u', '4']
# ['i', 'b']
# ['g', 'h']
# ['r', 'i']
# ['m', 'a']
# ['2', 'u']
# ['d', '7']
# ['5', '8']
# ['m', 'c']
# ['z', 'r']
# ['1', 'i']
# ['h', '0']
# ['b', 'j']
# ['0', 'x']
# ['n', '5']
# ['d', 'c']
# ['q', 'i']
# ['z', '5']
# ['e', 'k']
# ['s', '1']
# your passwords1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-66e7bfaa0bb2> in <module>
#       4   if (guess==list(password)):
#       5     print("your password"+"".join(guess))
# ----> 6     input()
#       7     break
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
if (guess==list(password)):
  print("your password"+"".join(guess))
  input()
  break
